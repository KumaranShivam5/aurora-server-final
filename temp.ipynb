# %%
import pandas as pd
df = pd.read_csv('cat-cross-match/matched_sources.csv')
df
# Out:
#                        name  ok          ra        dec    offset      cat_ra  \
# 0     2CXO J020052.2-092431   1   30.217678  -9.408798  0.000791   30.217678
# 1     2CXO J231518.9-591028   1  348.828827 -59.174549  0.001220  348.828827
# 2     2CXO J083642.7+532838   1  129.177966  53.477267  0.001673  129.177966
# 3     2CXO J190109.3-220005   1  285.288993 -22.001639  0.001791  285.288993
# 4     2CXO J193840.1+303028   1  294.667085  30.507841  0.001911  294.667085
# ...                     ...  ..         ...        ...       ...         ...
# 1296  2CXO J033130.5-275143   1   52.877428 -27.862157  0.953056   52.877500
# 1297  2CXO J084052.1+131823   1  130.217223  13.306390  0.971572  130.217500
# 1298  2CXO J112320.4+535631   1  170.835005  53.942171  0.975908  170.835000
# 1299  2CXO J100047.7+023551   1  150.198951   2.597604  0.978654  150.198700
# 1300  2CXO J160517.7-010955   1  241.323949  -1.165404  0.979254  241.324200
#
# ...

# %%
df['our_class'].value_counts()
# Out:
# AGN       783
# STAR      428
# PULSAR     38
# HMXB       15
# YSO        14
# CV         12
# LMXB        9
# ULX         2
# Name: our_class, dtype: int64

# %%
df['mw_class'].value_counts()
# Out:
# AGN       786
# YSO       278
# STAR      150
# LMXB       34
# PULSAR     22
# CV         19
# HMXB       12
# Name: mw_class, dtype: int64
