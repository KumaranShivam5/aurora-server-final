# %%
import pandas as pd 
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('../../not_on_git/final_classification/all_classified.csv' , usecols=['name' , 'ra' ,'dec' , 'significance' , 'prob' , 'class' , 'var_flag' , 'pileup_flag' , 'var_inter_index_b', 'var_intra_index_b' ,'streak_src_flag' , 'conf_flag' ,])
df
# Out:
#                          name  significance  var_flag  streak_src_flag  \
# 0       2CXO J003935.9-732725      3.294118         0                0
# 1       2CXO J003936.7-731249      4.157895         0                0
# 2       2CXO J004028.7-731106     14.422175         0                0
# 3       2CXO J004506.3-730056     10.447263         0                0
# 4       2CXO J004659.0-731918      2.444444         0                0
# ...                       ...           ...       ...              ...
# 269361  2CXO J220433.1-495916      2.651163         1                0
# 269362  2CXO J220508.3-495935      4.965517         1                0
# 269363  2CXO J220544.0-495505      2.857143         1                0
# 269364  2CXO J220555.6-500837      9.940400         1                0
# 269365  2CXO J220603.1-500911      9.246739         1                0
#
#         pileup_flag          ra        dec  conf_flag   class      prob  \
# ...

# %%
df.to_csv('all_clf.csv')

# %%
df = pd.read_csv('temp_files/x-ray-and-mw-feat-comparison.csv')
df =  df.set_index(['class','type'])
df
# Out:
#                          precision        recall      f1_score
# class  type
# AGN    all            96.8$\pm$0.1  97.6$\pm$0.2  97.2$\pm$0.1
#        x-ray+optical  94.9$\pm$0.2  97.0$\pm$0.1  96.0$\pm$0.1
#        X-ray+IR       95.8$\pm$0.1  96.4$\pm$0.2  96.1$\pm$0.2
#        no_mw          91.1$\pm$0.1  95.1$\pm$0.1  93.0$\pm$0.1
# STAR   all            96.1$\pm$0.1  95.7$\pm$0.1  95.9$\pm$0.1
#        x-ray+optical  94.1$\pm$0.3  93.2$\pm$0.1  93.7$\pm$0.2
#        X-ray+IR       95.2$\pm$0.2  94.4$\pm$0.2  94.8$\pm$0.2
#        no_mw          89.2$\pm$0.2  88.2$\pm$0.1  88.7$\pm$0.1
# YSO    all            92.8$\pm$0.2  95.4$\pm$0.3  94.1$\pm$0.2
#        x-ray+optical  88.6$\pm$0.3  93.9$\pm$0.4  91.2$\pm$0.3
#        X-ray+IR       91.7$\pm$0.7  95.0$\pm$0.2  93.3$\pm$0.4
#        no_mw          82.9$\pm$0.1  89.4$\pm$0.3  86.0$\pm$0.1
# HMXB   all            91.8$\pm$0.2  90.7$\pm$0.7  91.2$\pm$0.4
#        x-ray+optical  91.5$\pm$0.1  90.4$\pm$0.4  90.9$\pm$0.2
# ...

# %%
print(df.to_latex(escape=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
#        &       &     precision &        recall &      f1_score \\
# class & type &               &               &               \\
# \midrule
# AGN & all &  96.8$\pm$0.1 &  97.6$\pm$0.2 &  97.2$\pm$0.1 \\
#        & x-ray+optical &  94.9$\pm$0.2 &  97.0$\pm$0.1 &  96.0$\pm$0.1 \\
#        & X-ray+IR &  95.8$\pm$0.1 &  96.4$\pm$0.2 &  96.1$\pm$0.2 \\
#        & no_mw &  91.1$\pm$0.1 &  95.1$\pm$0.1 &  93.0$\pm$0.1 \\
# STAR & all &  96.1$\pm$0.1 &  95.7$\pm$0.1 &  95.9$\pm$0.1 \\
#        & x-ray+optical &  94.1$\pm$0.3 &  93.2$\pm$0.1 &  93.7$\pm$0.2 \\
#        & X-ray+IR &  95.2$\pm$0.2 &  94.4$\pm$0.2 &  94.8$\pm$0.2 \\
#        & no_mw &  89.2$\pm$0.2 &  88.2$\pm$0.1 &  88.7$\pm$0.1 \\
# YSO & all &  92.8$\pm$0.2 &  95.4$\pm$0.3 &  94.1$\pm$0.2 \\
#        & x-ray+optical &  88.6$\pm$0.3 &  93.9$\pm$0.4 &  91.2$\pm$0.3 \\
#        & X-ray+IR &  91.7$\pm$0.7 &  95.0$\pm$0.2 &  93.3$\pm$0.4 \\
# ...

# %%
df = pd.read_csv('temp_files/drop_feature_comparison.csv')
df =  df.set_index(['class','type'])
df
# Out:
#                     precision        recall      f1 score
# class  type
# AGN    all       96.8$\pm$0.1  97.6$\pm$0.2  97.2$\pm$0.1
#        no WISE   95.9$\pm$0.1  97.4$\pm$0.1  96.6$\pm$0.1
#        no 2MASS  96.7$\pm$0.2  97.3$\pm$0.2  97.0$\pm$0.1
#        no SDSS   96.6$\pm$0.1  97.5$\pm$0.1  97.0$\pm$0.1
#        no GAIA   96.4$\pm$0.1  97.0$\pm$0.1  96.7$\pm$0.1
# ...                       ...           ...           ...
# PULSAR no SDSS   41.8$\pm$2.6  43.4$\pm$3.0  42.6$\pm$2.7
#        no GAIA   34.7$\pm$1.4  41.0$\pm$1.6  37.6$\pm$1.4
#        no GALEX  42.1$\pm$1.2  44.2$\pm$1.5  43.1$\pm$1.3
#        no MIPS   41.1$\pm$2.6  42.6$\pm$3.1  41.8$\pm$2.7
#        no mw     28.2$\pm$1.9  18.6$\pm$0.7  22.4$\pm$0.9
#
# [64 rows x 3 columns]

# %%
print(df.to_latex(escape=False ))
# Out:
# \begin{tabular}{lllll}
# \toprule
#        &       &     precision &        recall &      f1 score \\
# class & type &               &               &               \\
# \midrule
# AGN & all &  96.8$\pm$0.1 &  97.6$\pm$0.2 &  97.2$\pm$0.1 \\
#        & no WISE &  95.9$\pm$0.1 &  97.4$\pm$0.1 &  96.6$\pm$0.1 \\
#        & no 2MASS &  96.7$\pm$0.2 &  97.3$\pm$0.2 &  97.0$\pm$0.1 \\
#        & no SDSS &  96.6$\pm$0.1 &  97.5$\pm$0.1 &  97.0$\pm$0.1 \\
#        & no GAIA &  96.4$\pm$0.1 &  97.0$\pm$0.1 &  96.7$\pm$0.1 \\
#        & no GALEX &  96.6$\pm$0.2 &  97.5$\pm$0.1 &  97.1$\pm$0.1 \\
#        & no MIPS &  96.7$\pm$0.2 &  97.4$\pm$0.1 &  97.0$\pm$0.1 \\
#        & no mw &  91.1$\pm$0.1 &  95.1$\pm$0.1 &  93.0$\pm$0.1 \\
# STAR & all &  96.1$\pm$0.1 &  95.7$\pm$0.1 &  95.9$\pm$0.1 \\
#        & no WISE &  95.9$\pm$0.2 &  95.5$\pm$0.1 &  95.7$\pm$0.1 \\
#        & no 2MASS &  95.0$\pm$0.3 &  94.2$\pm$0.1 &  94.6$\pm$0.1 \\
# ...

# %%
df = pd.read_csv('../../not_on_git/final_classification/all_classified.csv', index_col='name')
lx = df[df['class']=='LMXB']
hx = df[df['class']=='HMXB']
lx
# Out:
#                        significance  var_flag  streak_src_flag  pileup_flag  \
# name
# 2CXO J003727.6-721253      2.702703         0                0            0
# 2CXO J022701.8+615209      2.486486         0                0            0
# 2CXO J024004.1+611037      3.055556         0                0            0
# 2CXO J031839.1+415121      3.794872         0                0            0
# 2CXO J050558.9-680021      2.944444         0                0            0
# ...                             ...       ...              ...          ...
# 2CXO J233621.2+211329     55.334048         1                0            0
# 2CXO J145905.8-164804     12.628236         1                0            0
# 2CXO J145920.1-164541      7.426630         1                0            0
# 2CXO J145936.9-164219     23.607437         1                0            0
# 2CXO J160627.0+000205      7.132614         1                0            0
#
# ...

# %%
hx.to_csv('temp_files/HMXB.csv')

# %%
plt.hist(lx['prob'], density=True)
plt.show()

# %%
plt.hist(hx['prob'], density=True)
plt.show()

# %%
lx_low = lx.query("prob>0.35 and prob < 0.55")
lx_high = lx.query("prob>0.85")

# %%
hx_low = hx.query("prob>0.35 and prob < 0.55")
hx_high = hx.query("prob>0.85")

# %%
hx_low['b-csc'].isna().sum() / len(lx_low)*100
# Out:
# 0.0

# %%
import numpy as np

# %%
for c in lx.columns.tolist()[:]:
    try:
        fig , ax = plt.subplots(nrows = 1 , ncols=2, figsize = (16,6))
        ax = np.ravel(ax)
        lx_low_count = int((lx_low[c].isna().sum()))
        lx_high_count = int((lx_high[c].isna().sum()))
        hx_low_count = int((hx_low[c].isna().sum()))
        hx_high_count = int((hx_high[c].isna().sum()))
        ax[0].hist(lx_low[c], histtype='step' , label=f'low : {lx_low_count} / {len(lx_low)}', color='cyan')
        ax[0].hist(lx_high[c] ,  histtype='step', label=f'High: {lx_high_count} / {len(lx_high)}', color='crimson')
        ax[1].hist(hx_low[c], histtype='step' , label=f'low : {hx_low_count} / {len(hx_low)}', color='cyan')
        ax[1].hist(hx_high[c] ,  histtype='step', label=f'High: {hx_high_count} / {len(hx_high)}', color='crimson')
        for a in ax:
            a.legend(fontsize=16)
            a.set_xlabel(c)
        ax[0].set_title('LMXB')
        ax[1].set_title('HMXB')
        plt.savefig(f'temp_files/temp_plots/{c}.jpg')
        # plt.show()
        plt.close()
    except ValueError as e:
        print('>>>>>>>>>> ERROR :', c , e)
# Out:
# /home/kumaran/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6623: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /home/kumaran/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6624: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# >>>>>>>>>> ERROR : G-W2 autodetected range of [nan, nan] is not finite
# /home/kumaran/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6623: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /home/kumaran/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6624: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# >>>>>>>>>> ERROR : Bp-W3 autodetected range of [nan, nan] is not finite

# %%
for c in hx.columns.tolist():
    low_count = int((hx_low[c].isna().sum()) )
    high_count = int((hx_high[c].isna().sum()))
    plt.hist(hx_low[c], histtype='step' , label=f'low : {low_count} / {len(hx_low)}')
    plt.hist(hx_high[c] ,  histtype='step', label=f'High: {high_count} / {len(hx_high)}')
    plt.legend()
    plt.savefig(f'temp_files/temp-hmxb_plots/{c}_hmxb.jpg')
    plt.close()
